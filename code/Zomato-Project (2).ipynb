# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: selenium in c:\users\prajw\appdata\roaming\python\python311\site-packages (4.21.0)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (2.0.7)
# Requirement already satisfied: trio~=0.17 in c:\users\prajw\appdata\roaming\python\python311\site-packages (from selenium) (0.25.1)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\prajw\appdata\roaming\python\python311\site-packages (from selenium) (0.11.1)
# Requirement already satisfied: certifi>=2021.10.8 in c:\programdata\anaconda3\lib\site-packages (from selenium) (2024.6.2)
# Requirement already satisfied: typing_extensions>=4.9.0 in c:\programdata\anaconda3\lib\site-packages (from selenium) (4.9.0)
# Requirement already satisfied: attrs>=23.2.0 in c:\users\prajw\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (23.2.0)
# Requirement already satisfied: sortedcontainers in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: idna in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.4)
# Requirement already satisfied: outcome in c:\users\prajw\appdata\roaming\python\python311\site-packages (from trio~=0.17->selenium) (1.3.0.post0)
# Requirement already satisfied: sniffio>=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.3.0)
# Requirement already satisfied: cffi>=1.14 in c:\programdata\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.16.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\prajw\appdata\roaming\python\python311\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: pysocks!=1.5.7,<2.0,>=1.5.6 in c:\programdata\anaconda3\lib\site-packages (from urllib3[socks]<3,>=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import time
from selenium import webdriver
from selenium.webdriver.common.by import By

# %%
driver = webdriver.Chrome()

# %%
# url = "https://www.zomato.com/bangalore"

# %%
# driver.get(url)
# time.sleep(2)

# %%
# for k in range(20):
#         driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
#         time.sleep(2)

# %%
#len(driver.find_elements(By.CLASS_NAME, "jumbo-tracker"))
# Out:
# 501

# %%
#soup = BeautifulSoup(driver.page_source)

# %%
#soup

# %%
def scrape_zomato(city):
    url = f"https://www.zomato.com/{city}"
    driver.get(url)
    time.sleep(1)
    for k in range(1):
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(2)
    soup = BeautifulSoup(driver.page_source)
    restaurants = soup.find_all('div',{"class":"sc-dzOgQY fnDzyq"})
    restaurant_data = {'Restaurant': [], 'Rating': [], 'Restaurant_Type': [],'Price': [],  'Location': [], 'Link': [],'timings':[],'dish_name':[],"restuarent_known_for":[],"delivery_review_number":[]}
    for res in restaurants:
        try:
            restaurant_data['Restaurant'].append(res.find('h4',class_="sc-1hp8d8a-0 sc-iEPtyo fKawif").text)
        except:
            restaurant_data['Restaurant'].append("NA")
        try:
            restaurant_data['Rating'].append(res.find('div',class_="sc-1q7bklc-1 cILgox").text)
        except:
            restaurant_data['Rating'].append("NA")
        try:
            restaurant_data['Restaurant_Type'].append(res.find('p',class_="sc-1hez2tp-0 sc-gUlUPW gQHQnh").text)
        except:
            restaurant_data['Restaurant_Type'].append("NA")
        try:
            restaurant_data['Price'].append(res.find('p',class_="sc-1hez2tp-0 sc-gUlUPW iMvhva").text)
        except:
            restaurant_data['Price'].append("NA")
        try:
            restaurant_data['Location'].append(res.find('p',class_="sc-1hez2tp-0 sc-kQZOhr kWLunQ").text)
        except:
            restaurant_data['Location'].append("NA")
        try:
            restaurant_data['Link'].append('https://www.zomato.com' + res.find('a', class_="sc-hZeNU cijfCJ")['href'])
        except:
            restaurant_data['Link'].append('NA')
        time.sleep(1)
        lis=scrape('https://www.zomato.com' + res.find('a', class_="sc-hZeNU cijfCJ")['href'])
        restaurant_data['timings'].append(lis[0])
        restaurant_data['dish_name'].append(lis[1])
        restaurant_data['restuarent_known_for'].append(lis[2])
        restaurant_data['delivery_review_number'].append(lis[3])

    df = pd.DataFrame(restaurant_data)
    return df

# %%
def scrape(ur):
    driver.get(ur)
    time.sleep(1)
    rest = BeautifulSoup(driver.page_source)
    #restaurant_data = {'timings': [], 'Rating': [], 'Restaurant_Type': [],'Price': [],  'Location': [], 'Link': []}
    k=[]
    try:
        k.append(rest.find('span',class_="sc-kasBVs dfwCXs").text)
    except:
        k.append("NA")
    try:
        k.append(rest.find('p',class_="sc-1hez2tp-0 sc-bIGiiI jChVuK").text)
    except:
        k.append("NA")
    try:
        k.append(rest.find('p',class_="sc-1hez2tp-0 sc-bIGiiI jChVuK").text)
    except:
        k.append("NA")
        

    try:
        k.append(rest.find_all('div',class_="sc-1q7bklc-8 kEgyiI")[2].text)
    except:
        k.append("NA")
        
    return k
    
#     try:
#         restaurant_data['Rating'].append(res.find('div',class_="sc-1q7bklc-1 cILgox").text)
#     except:
#         restaurant_data['Rating'].append("NA")
#     try:
#         restaurant_data['Restaurant_Type'].append(res.find('p',class_="sc-1hez2tp-0 sc-gUlUPW gQHQnh").text)
#     except:
#         restaurant_data['Restaurant_Type'].append("NA")
#     try:
#         restaurant_data['Price'].append(res.find('p',class_="sc-1hez2tp-0 sc-gUlUPW iMvhva").text)
#     except:
#         restaurant_data['Price'].append("NA")
#     try:
#         restaurant_data['Location'].append(res.find('p',class_="sc-1hez2tp-0 sc-kQZOhr kWLunQ").text)
#     except:
#         restaurant_data['Location'].append("NA")
#     try:
#         restaurant_data['Link'].append('https://www.zomato.com' + res.find('a', class_="sc-hZeNU cijfCJ")['href'])
#     except:
#         restaurant_data['Link'].append('NA')

#     df = pd.DataFrame(restaurant_data)
#     return df

# %%
driver.get("https://www.zomato.com/bangalore/muro-church-street-bangalore/info")
time.sleep(1)
rest = BeautifulSoup(driver.page_source)
print(rest.find('span',class_="sc-kasBVs dfwCXs").text)
# Out:
# 12midnight – 1am, 12noon – 11:45pm (Today)

# %%
hyderabad_data = scrape_zomato("bangalore")

# %%
hyderabad_data
# Out:
#                              Restaurant Rating  \
# 0                                  Muro    4.1
# 1                         Öz by Kebapci    4.5
# 2                          Secret Story    3.9
# 3           Over Coffee Cafe & Wine Bar    4.7
# 4                        Oney Brewhouse    4.1
# 5   Babylonia - Global Food & Cocktails    4.5
# 6                               Bramble    4.4
# 7                                Homiga    4.4
# 8                                   Flo    4.2
# 9                               Alchemy    4.2
# 10                         Ouzo By Fire    New
# 11                Long Boat Brewing Co.    4.3
# 12                     Toca Koramangala    4.1
# 13                                  Oia    4.2
# 14                           Farzi Cafe    4.2
# 15                                 Nusa    3.9
# 16                           Dishkeyaun    4.0
# 17                   Ironhill Bengaluru    4.5
# 18                         Jook Taproom    4.4
# 19                    Absolute Shawarma    3.9
# 20                         Scottish Pub    New
# 21                 Magic Mocktails Cafe      -
# 22               Mannheim Craft Brewery    New
# 23                                Roxie    4.6
# 24                SkyDeck By Sherlock's    4.2
# 25       Prime Golf - Brewing & Golfing    4.3
# 26                              Magique    4.1
# 27          Byg Brewski Brewing Company    4.6
# 28            Citrus - The Leela Palace    4.0
# 29                                Phurr    4.4
# 30           Geometry Brewery & Kitchen    4.3
# 31                              Bastian    New
# 32     The Terrace at Gilly's Redefined    4.4
# 33                       BLR Brewing Co    4.4
# 34                                KLING    4.2
# 35                     The Bier Library    4.5
# 36                VYANA - World Cuisine    4.0
# 37                         Uru Brewpark    4.3
# 38               Mitico Coffee Roasters    4.4
# 39                   Candles  Brewhouse    4.3
# 40                         Toca Brigade    4.1
# 41                         One8 Commune    3.9
# 42                                 Boho    4.1
# 43                                 Hoot    4.2
# 44   Moglu - The Edgy Veggie Restaurant    3.9
#
#                                       Restaurant_Type           Price  \
# 0                                     Thai, Cantonese  ₹3,000 for two
# 1              Turkish, Mediterranean, Middle Eastern  ₹1,800 for two
# 2   Continental, Asian, North Indian, Fast Food, D...  ₹1,500 for two
# 3        European, Italian, Continental, Cafe, Coffee  ₹1,200 for two
# 4   American, Continental, Italian, South Indian, ...  ₹1,500 for two
# 5   Continental, North Indian, Asian, Italian, Mug...  ₹1,500 for two
# 6   Continental, Asian, North Indian, Italian, Bar...  ₹1,800 for two
# 7                                       Korean, Asian  ₹1,500 for two
# 8   Asian, Thai, Continental, Finger Food, Sushi, ...  ₹1,900 for two
# 9   North Indian, Continental, Biryani, Desserts, ...  ₹3,300 for two
# 10                       Goan, Mangalorean, Beverages  ₹1,000 for two
# 11  Asian, Chinese, North Indian, Pizza, South Ind...  ₹2,600 for two
# 12  Chinese, Fast Food, Steak, Pasta, Asian, Birya...  ₹1,400 for two
# 13  Continental, Asian, Seafood, Salad, Pizza, Nor...  ₹2,500 for two
# 14                             North Indian, Desserts  ₹1,900 for two
# 15  North Indian, Asian, Continental, European, So...  ₹1,500 for two
# 16                   Modern Indian, Biryani, Desserts  ₹2,000 for two
# 17  North Indian, Continental, Asian, Pizza, Fast ...  ₹2,000 for two
# 18  North Indian, South Indian, Chinese, Pizza, Fa...  ₹1,600 for two
# 19  Shawarma, Fast Food, Burger, Pizza, Wraps, Mom...    ₹300 for two
# 20  Asian, Chinese, Burger, North Indian, Continen...  ₹1,000 for two
# 21  Beverages, Pizza, Burger, Sandwich, Fast Food,...    ₹200 for two
# 22  South Indian, North Indian, Continental, Desse...  ₹1,500 for two
# 23  Continental, Asian, North Indian, European, Am...  ₹2,600 for two
# 24  Continental, Chinese, Finger Food, North India...  ₹1,800 for two
# 25                           Modern Indian, Beverages  ₹2,000 for two
# 26  Asian, Modern Indian, Continental, Italian, No...  ₹1,700 for two
# 27  Continental, North Indian, Asian, Fast Food, P...  ₹2,000 for two
# 28         North Indian, Continental, Asian, Desserts  ₹4,700 for two
# 29                          North Indian, Continental  ₹2,000 for two
# 30  Chinese, North Indian, Italian, Continental, P...  ₹1,800 for two
# 31                                 Continental, Greek  ₹2,000 for two
# 32  Continental, Finger Food, Chinese, North India...  ₹2,000 for two
# 33  North Indian, Continental, Chinese, Italian, B...  ₹1,500 for two
# 34  Continental, European, Asian, Chinese, North I...  ₹1,500 for two
# 35  North Indian, Pizza, European, American, Bar F...  ₹1,800 for two
# 36  Italian, Oriental, Continental, Chinese, Salad...  ₹1,700 for two
# 37  Continental, North Indian, Italian, Chinese, A...  ₹2,200 for two
# 38  Cafe, Continental, Italian, Burger, North Indi...    ₹900 for two
# 39  Italian, Continental, American, Pizza, North I...  ₹2,500 for two
# 40  Chinese, Fast Food, Steak, Pasta, Asian, Birya...  ₹1,200 for two
# 41  North Indian, Chinese, Pasta, Sushi, Continent...  ₹3,000 for two
# 42  Continental, Asian, American, Mexican, Beverag...  ₹2,000 for two
# 43      Continental, Italian, North Indian, Beverages  ₹2,000 for two
# 44  Bakery, Modern Indian, Desserts, Beverages, Am...  ₹1,800 for two
#
#                                              Location  \
# 0                            Church Street, Bangalore
# 1                                  UB City, Bangalore
# 2                              Indiranagar, Bangalore
# 3                             Lavelle Road, Bangalore
# 4                          Cunningham Road, Bangalore
# 5                    Koramangala 7th Block, Bangalore
# 6                                Jayanagar, Bangalore
# 7                           Forum Rex Walk, Bangalore
# 8                            Church Street, Bangalore
# 9    The Chancery Pavilion, Residency Road, Bangalore
# 10                             Indiranagar, Bangalore
# 11                            Marathahalli, Bangalore
# 12                   Koramangala 5th Block, Bangalore
# 13                                  Hennur, Bangalore
# 14                                 UB City, Bangalore
# 15           Varthur Main Road, Whitefield, Bangalore
# 16                          Forum Rex Walk, Bangalore
# 17                            Marathahalli, Bangalore
# 18                             Indiranagar, Bangalore
# 19                              Chanapatna, Bangalore
# 20                          St. Marks Road, Bangalore
# 21                              Chanapatna, Bangalore
# 22               Garuda Mall, Magrath Road, Bangalore
# 43  https://www.zomato.com/bangalore/hoot-sarjapur...
# 44  https://www.zomato.com/bangalore/moglu-the-edg...
#
#                                               timings dish_name  \
# 0          12midnight – 1am, 12noon – 11:45pm (Today)        NA
# 1                           12:30pm – 12:30am (Today)        NA
# 2                                12noon – 1am (Today)        NA
# 3                            12noon – 10:30pm (Today)        NA
# 4                         12noon – 12midnight (Today)        NA
# 5                            12noon – 12:30am (Today)        NA
# 6                                12noon – 1am (Today)        NA
# 7   24 Hours, 12:30pm – 4:30pm, 6:30pm – 12midnigh...        NA
# 8                                12noon – 1am (Today)        NA
# 9                         12noon – 12midnight (Today)        NA
# 10                                       Opens at 7pm        NA
# 11   12midnight – 1:30am, 12noon – 12midnight (Today)        NA
# 12                          11am – 12midnight (Today)        NA
# 13      12midnight – 1am, 12noon – 12midnight (Today)        NA
# 14                           12noon – 11:45pm (Today)        NA
# 15      12midnight – 1am, 12noon – 12midnight (Today)        NA
# 16                                    Opens at 6:30pm        NA
# 17                               12noon – 1am (Today)        NA
# 18                        12noon – 12midnight (Today)        NA
# 19                                                 NA        NA
# 20                        12noon – 12midnight (Today)        NA
# 21                                                 NA        NA
# 22                              12noon – 11pm (Today)        NA
# 23                               12noon – 1am (Today)        NA
# 24                              11:30am – 1am (Today)        NA
# 25                        12noon – 12midnight (Today)        NA
# 26      12midnight – 1am, 12noon – 12midnight (Today)        NA
# 27                               12noon – 1am (Today)        NA
# 28              9am – 10am, 12:30pm – 11:30pm (Today)        NA
# 29                                       Opens at 7pm        NA
# 30                              11:30am – 1am (Today)        NA
# 31                                       Opens at 7pm        NA
# 32                           12noon – 12:30am (Today)        NA
# 33                        12noon – 12midnight (Today)        NA
# 34                               12noon – 1am (Today)        NA
# 35                               12noon – 1am (Today)        NA
# 36                              12noon – 11pm (Today)        NA
# 37                              10:30am – 1am (Today)        NA
# 38                          11am – 12midnight (Today)        NA
# 39                        12noon – 12midnight (Today)        NA
# 40                          11am – 12midnight (Today)        NA
# 41                              12:30pm – 1am (Today)        NA
# 42                        12noon – 12midnight (Today)        NA
# 43                           12noon – 12:30am (Today)        NA
# 44                          11:30am – 11:30pm (Today)        NA
#
#    restuarent_known_for delivery_review_number
# 0                    NA                    292
# 1                    NA                    819
# 2                    NA                  3,964
# 3                    NA                    560
# 4                    NA                    231
# 5                    NA                  1,203
# 6                    NA                  3,660
# 7                    NA                    207
# 8                    NA                  1,244
# 9                    NA                  2,991
# 10                   NA                     53
# 11                   NA                  7,426
# 12                   NA                    486
# 13                   NA                  8,503
# 14                   NA                  3,710
# 15                   NA                  3,773
# 16                   NA                    180
# 17                   NA                  32.6K
# 18                   NA                  2,289
# 19                   NA                     NA
# 20                   NA                    505
# 21                   NA                     NA
# 22                   NA                    346
# 23                   NA                  10.9K
# 24                   NA                  4,494
# 25                   NA                  1,168
# 26                   NA                  4,309
# 27                   NA                  38.1K
# 28                   NA                  1,060
# 29                   NA                  2,136
# 30                   NA                  3,561
# 31                   NA                    143
# 32                   NA                  4,632
# 33                   NA                  5,059
# 34                   NA                    217
# 35                   NA                  14.5K
# 36                   NA                    976
# 37                   NA                    17K
# 38                   NA                    275
# 39                   NA                  4,968
# 40                   NA                     56
# 41                   NA                    512
# 42                   NA                  3,621
# 43                   NA                  13.5K
# 44                   NA                    128
