# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Setting display options
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Adjust width to display DataFrame without truncation
pd.set_option('display.max_colwidth', None)  # Show full column width without truncation

# %%
df = pd.read_csv('FINAL.csv')

# %%
df
# Out:
#      Unnamed: 0  Restuarantid  \
# 0             0             1
# 1             1             2
# 2             2             3
# 3             3             4
# 4             4             5
# 5             5             6
# 6             6             7
# 7             7             8
# 8             8             9
# 9             9            10
# 10           10            11
# 11           11            12
# 12           12            13
# 13           13            14
# 14           14            15
# 15           15            16
# 16           16            17
# 17           17            18
# 18           18            19
# 19           19            20
# 20           20            21
# 21           21            22
# 22           22            23
# 23           23            24
# 24           24            25
# 25           25            26
# 26           26            27
# 27           27            28
# 28           28            29
# 29           29            30
# ...

# %% [markdown]
# ### Why do EDA
#
# - Model building
# - Analysis and reporting
# - Validate assumptions
# - Handling missing values
# - feature engineering
# - detecting outliers

# %%
# Remember it is an iterative process

# %% [markdown]
# ### Column Types
#
# - **Numerical** - Restuarantid,Price_for_two,Dining_Review_Count,Dining_Rating,Delivery_Rating,Delivery_Review_Count,Price per Person,Total Review Count,Popularity score
# - **Categorical** - price range category,Rating Category,Cuisine,Restaurant_Type,Area
# - **Mixed** - Restaurant,Timing

# %% [markdown]
# ### Univariate Analysis
#
# Univariate analysis focuses on analyzing each feature in the dataset independently.
#
# - **Distribution analysis**: The distribution of each feature is examined to identify its shape, central tendency, and dispersion.
#
# - **Identifying potential issues**: Univariate analysis helps in identifying potential problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# #### The shape of a data distribution refers to its overall pattern or form as it is represented on a graph. Some common shapes of data distributions include:
#
# - **Normal Distribution**: A symmetrical and bell-shaped distribution where the mean, median, and mode are equal and the majority of the data falls in the middle of the distribution with gradually decreasing frequencies towards the tails.
#
# - **Skewed Distribution**: A distribution that is not symmetrical, with one tail being longer than the other. It can be either positively skewed (right-skewed) or negatively skewed (left-skewed).
#
# - **Bimodal Distribution**: A distribution with two peaks or modes.
#
# - **Uniform Distribution**: A distribution where all values have an equal chance of occurring.
#
# The shape of the data distribution is important in identifying the presence of outliers, skewness, and the type of statistical tests and models that can be used for further analysis.

# %% [markdown]
# #### **Dispersion** is a statistical term used to describe the spread or variability of a set of data. It measures how far the values in a data set are spread out from the central tendency (mean, median, or mode) of the data.
#
# There are several measures of dispersion, including:
#
# - **Range**: The difference between the largest and smallest values in a data set.
#
# - **Variance**: The average of the squared deviations of each value from the mean of the data set.
#
# - **Standard Deviation**: The square root of the variance. It provides a measure of the spread of the data that is in the same units as the original data.
#
# - **Interquartile range (IQR)**: The range between the first quartile (25th percentile) and the third quartile (75th percentile) of the data.
#
# Dispersion helps to describe the spread of the data, which can help to identify the presence of outliers and skewness in the data.

# %% [markdown]
# ### Steps of doing Univariate Analysis on Numerical columns
#
# - **Descriptive Statistics**: Compute basic summary statistics for the column, such as mean, median, mode, standard deviation, range, and quartiles. These statistics give a general understanding of the distribution of the data and can help identify skewness or outliers.
#
# - **Visualizations**: Create visualizations to explore the distribution of the data. Some common visualizations for numerical data include histograms, box plots, and density plots. These visualizations provide a visual representation of the distribution of the data and can help identify skewness an outliers.
#
# - **Identifying Outliers**: Identify and examine any outliers in the data. Outliers can be identified using visualizations. It is important to determine whether the outliers are due to measurement errors, data entry errors, or legitimate differences in the data, and to decide whether to include or exclude them from the analysis.
#
# - **Skewness**: Check for skewness in the data and consider transforming the data or using robust statistical methods that are less sensitive to skewness, if necessary.
#
# - **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# ### Price per Person
#
# **conclusions**
#
# - Price per Person is normally(almost) distributed
# - no missing values
# - There are some outliers(but they are valid)

# %%
df['Price per Person'].describe()
# Out:
# count     501.000000
# mean      842.075848
# std       383.044883
# min       100.000000
# 25%       600.000000
# 50%       800.000000
# 75%      1000.000000
# max      2500.000000
# Name: Price per Person, dtype: float64

# %%
df['Price per Person'].plot(kind='hist',bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Price per Person'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Price per Person'].skew()
# Out:
# 1.1535403602030727

# %%
df['Price per Person'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Price per Person'] > 1800]
# Out:
#      Unnamed: 0  Restuarantid                          Restaurant  \
# 20           20            21           Citrus - The Leela Palace
# 100         100           101  JW Kitchen - JW Marriott Bengaluru
# 189         189           190                                LUPA
# 282         282           283          Jamavar - The Leela Palace
# 458         458           459               Rim Naam - The Oberoi
#
#                                        Restaurant_Type  Price_for_two  \
# 20          North Indian, Continental, Asian, Desserts           4700
# 100  North Indian, Continental, Mughlai, Beverages,...           5000
# 189  Mediterranean, European, Italian, Salad, Desse...           5000
# 282                         North Indian, South Indian           5000
# 458                     Thai, Asian, Seafood, Desserts           5000
#
#            Cuisine                                         Location  \
# 20    North Indian    The Leela Palace, Old Airport Road, Bangalore
# ...

# %%
df['Price per Person'].isnull().sum()/len(df['Price per Person'])
# Out:
# 0.0

# %%
df["Price per Person"].value_counts()
# Out:
# Price per Person
# 1000    58
# 900     57
# 500     45
# 750     36
# 600     36
# 1250    34
# 700     29
# 800     23
# 850     20
# 1750    19
# 950     16
# 550     14
# 1500    13
# 650     12
# 475     12
# 300      8
# 350      8
# 1100     8
# 400      6
# 250      5
# 1300     5
# 200      4
# 2500     4
# 100      3
# 275      3
# 150      3
# 450      3
# 375      2
# 1150     2
# 1050     2
# 425      2
# 980      1
# 175      1
# 1400     1
# 1800     1
# 2350     1
# 225      1
# 1650     1
# 1550     1
# 125      1
# Name: count, dtype: int64

# %%
df["Total_Rating"]=df["Dining_Rating"]+df["Delivery_Rating"]

# %% [markdown]
# ### Total Review Count
#
# **conclusions**
#
# - The data is highly(positively) skewed
# - there are outliers but they are genuine data of genuine restuarant
# -

# %%
df['Total Review Count'].describe()
# Out:
# count       501.000000
# mean       4041.748503
# std        8694.034213
# min           0.000000
# 25%         393.000000
# 50%        1522.000000
# 75%        4349.000000
# max      102981.000000
# Name: Total Review Count, dtype: float64

# %%
df['Total Review Count'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Total Review Count'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Total Review Count'].skew()
# Out:
# 7.3105139251980695

# %%
df['Total Review Count'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Total Review Count'] >20000]
# Out:
#      Unnamed: 0  Restuarantid                              Restaurant  \
# 19           19            20                      Ironhill Bengaluru
# 27           27            28             Byg Brewski Brewing Company
# 41           41            42                            Uru Brewpark
# 96           96            97                         TBC- Sky Lounge
# 132         132           133                               Communiti
# 396         396           397                                 Al Daaz
# 408         408           409                       Empire Restaurant
# 432         432           433  Paradise Biryani - A Legend Since 1953
# 453         453           454                    Sardarji Londonwaley
# 461         461           462                                  Onesta
# 472         472           473   Hyderabad Biryaani House - Since 2003
# 476         476           477                           Meghana Foods
# ...

# %%
df['Total Review Count'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Dining_Rating
#
# **conclusions**
#
# - The data is highly(negatively) skewed
# - there are outliers but they are genuine data of genuine restuarant
# - some of dining ratings are not present that means they dont do dining i.e cloud kitchen

# %%
df['Dining_Rating'].describe()
# Out:
# count    501.000000
# mean       4.146108
# std        0.647402
# min        0.000000
# 25%        4.100000
# 50%        4.300000
# 75%        4.400000
# max        4.900000
# Name: Dining_Rating, dtype: float64

# %%
df['Dining_Rating'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Dining_Rating'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Dining_Rating'].skew()
# Out:
# -5.248453184381825

# %%
df['Dining_Rating'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Dining_Rating'] <3.5]
# Out:
#      Unnamed: 0  Restuarantid            Restaurant  \
# 11           11            12  Magic Mocktails Cafe
# 21           21            22     Absolute Shawarma
# 31           31            32               Bastian
# 189         189           190                  LUPA
# 204         204           205             Tall Oaks
# 218         218           219               Roastea
# 245         245           246  Gannet Bar & Kitchen
# 267         267           268                Neemsi
# 269         269           270             Just Loaf
# 291         291           292        Cafe Centralis
# 330         330           331    Escape by Brewklyn
# 361         361           362               Dobaraa
# 370         370           371            Tiger Yaki
# 415         415           416          Sozo Skyline
# 453         453           454  Sardarji Londonwaley
#
#                                                                          Restaurant_Type  \
# ...

# %%
df['Dining_Rating'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Delivery_Rating
#
# **conclusions**
#
# - The data is normally distributed
# - there are outliers but they are genuine data of genuine restuarant(like 0)
# - some of delivery ratings are not present that means they dont do delivery i.e ony dine in restuarants

# %%
df['Delivery_Rating'].describe()
# Out:
# count    501.000000
# mean       2.723752
# std        1.877630
# min        0.000000
# 25%        0.000000
# 50%        3.900000
# 75%        4.100000
# max        4.700000
# Name: Delivery_Rating, dtype: float64

# %%
df['Delivery_Rating'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df['Delivery_Rating'].plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df['Delivery_Rating'].skew()
# Out:
# -0.7279284933908777

# %%
df['Delivery_Rating'].plot(kind='box')
# Out:
# <Axes: >

# %%
df[df['Delivery_Rating']<3.5]
# Out:
#      Unnamed: 0  Restuarantid  \
# 0             0             1
# 3             3             4
# 4             4             5
# 6             6             7
# 7             7             8
# 8             8             9
# 11           11            12
# 14           14            15
# 15           15            16
# 16           16            17
# 17           17            18
# 18           18            19
# 21           21            22
# 25           25            26
# 26           26            27
# 28           28            29
# 29           29            30
# 30           30            31
# 31           31            32
# 32           32            33
# 35           35            36
# 36           36            37
# 37           37            38
# 38           38            39
# 40           40            41
# 43           43            44
# 44           44            45
# 47           47            48
# 48           48            49
# 51           51            52
# ...

# %%
df['Delivery_Rating'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Steps of doing Univariate Analysis on Categorical columns
#
# **Descriptive Statistics**: Compute the frequency distribution of the categories in the column. This will give a general understanding of the distribution of the categories and their relative frequencies.
#
# **Visualizations**: Create visualizations to explore the distribution of the categories. Some common visualizations for categorical data include count plots and pie charts. These visualizations provide a visual representation of the distribution of the categories and can help identify any patterns or anomalies in the data.
#
# **Missing Values**: Check for missing values in the data and decide how to handle them. Missing values can be imputed or excluded from the analysis, depending on the research question and the data set.
#
# **Conclusion**: Summarize the findings of the EDA and make decisions about how to proceed with further analysis.

# %% [markdown]
# categorical: price range category,Rating Category,Cuisine,Restaurant_Type,Area

# %% [markdown]
# ### price range category
#
# **conclusions**
#
# - there are medium price restuarants more than low price
# -

# %%
df['price range category'].value_counts()
# Out:
# price range category
# Medium    302
# Low       107
# High       92
# Name: count, dtype: int64

# %%
df['price range category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='price range category'>

# %%
df['price range category'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['price range category'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Rating Category
#
# **conclusions**
#
# - a lot of restuarants are good rated
# - restuarants that are below average has not given any value

# %%
df['Rating Category'].value_counts()
# Out:
# Rating Category
# Good             336
# Excellent         91
# Average           64
# Below Average     10
# Name: count, dtype: int64

# %%
df['Rating Category'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Rating Category'>

# %%
df['Rating Category'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Rating Category'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Cuisine
#
# **conclusions**
#
# - a lot of restuarants have some unique cuisines
# -

# %%
df['Cuisine'].value_counts()
# Out:
# Cuisine
# North Indian      135
# Continental        74
# Asian              36
# Cafe               30
# Chinese            27
# Bar Food           21
# Italian            21
# Pizza              11
# South Indian       11
# Finger Food        11
# Biryani             9
# American            9
# Japanese            9
# Burger              7
# Modern Indian       7
# Thai                6
# Andhra              5
# Kerala              5
# BBQ                 5
# Seafood             4
# Bakery              4
# European            4
# Sushi               3
# Korean              3
# Mediterranean       3
# Parsi               2
# Vietnamese          2
# Arabian             2
# Goan                2
# Salad               2
# Pasta               2
# Burmese             2
# Desserts            2
# Beverages           2
# Tea                 2
# Mexican             2
# Mangalorean         2
# French              1
# Bubble Tea          1
# Irish               1
# Momos               1
# ...

# %%
df['Cuisine'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cuisine'>

# %%
df['Cuisine'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
df['Cuisine'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### Steps of doing Bivariate Analysis
#
# - Select 2 cols
# - Understand type of relationship
#     1. **Numerical - Numerical**<br>
#         a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots<br>
#         b. Check correlation coefficent to check linear relationship
#     2. **Numerical - Categorical** - create visualizations that compare the distribution of the numerical data across different categories of the categorical data.<br>
#         a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots<br>
#     3. **Categorical - Categorical**<br>
#         a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.<br>
#         b. You can plots like heatmap, stacked barplots, treemaps
#
# - Write your conclusions

# %% [markdown]
# ### Rating Category	vs price range category
#
# **conclusions**
#
# - a lot of restuarants have some unique cuisines
# -

# %%
df1=df.loc[:,["Restuarantid","Price_for_two","Dining_Review_Count","Dining_Rating","Delivery_Rating","Delivery_Review_Count","Price per Person","Total Review Count","Popularity score"]]

# %%
df
# Out:
#      Unnamed: 0  Restuarantid  \
# 0             0             1
# 1             1             2
# 2             2             3
# 3             3             4
# 4             4             5
# 5             5             6
# 6             6             7
# 7             7             8
# 8             8             9
# 9             9            10
# 10           10            11
# 11           11            12
# 12           12            13
# 13           13            14
# 14           14            15
# 15           15            16
# 16           16            17
# 17           17            18
# 18           18            19
# 19           19            20
# 20           20            21
# 21           21            22
# 22           22            23
# 23           23            24
# 24           24            25
# 25           25            26
# 26           26            27
# 27           27            28
# 28           28            29
# 29           29            30
# ...

# %%
pd.crosstab(df['Rating Category'],df['price range category'],normalize='columns')*100
# Out:
# price range category       High        Low     Medium
# Rating Category
# Average               10.869565  25.233645   8.940397
# Below Average          1.086957   1.869159   2.317881
# Excellent             23.913043  13.084112  18.211921
# Good                  64.130435  59.813084  70.529801

# %%
sns.heatmap(pd.crosstab(df['Rating Category'],df['price range category'],normalize='columns')*100)
# Out:
# <Axes: xlabel='price range category', ylabel='Rating Category'>

# %%
pd.crosstab(df['Rating Category'],df['price range category'],normalize='index').plot(kind='bar',stacked=True)
# Out:
# <Axes: xlabel='Rating Category'>

# %%
sns.barplot(x="Rating Category",y='Price per Person',hue="price range category",data=df)
# Out:
# <Axes: xlabel='Rating Category', ylabel='Price per Person'>

# %%
# survived and age

df[df['Rating Category'] == "Excellent"]['Price per Person'].plot(kind='kde',label='Excellent')
df[df['Rating Category'] == "Good"]['Price per Person'].plot(kind='kde',label='Good')
# df[df['Rating Category'] == "Average"]['Price per Person'].plot(kind='kde',label='Average')
# df[df['Rating Category'] == "Below Average"]['Price per Person'].plot(kind='kde',label='Below Average')

plt.legend()
plt.show()

# %%
df1
# Out:
#      Restuarantid  Price_for_two  Dining_Review_Count  Dining_Rating  \
# 0               1           1800                  819            4.5
# 1               2           1200                  560            4.7
# 2               3           1500                 1203            4.5
# 3               4           1500                  231            4.1
# 4               5           1500                  207            4.4
# 5               6           1900                 1244            4.2
# 6               7           1000                   53            4.0
# 7               8           3300                 2991            4.2
# 8               9           2000                  180            4.0
# 9              10           1900                 3710            4.2
# 10             11           1400                  486            4.1
# 11             12            200                    0            0.0
# 12             13           1600                 2289            4.4
# ...

# %%
sns.heatmap(df1.corr())
# Out:
# <Axes: >

# %%
sns.pairplot(df1)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...
